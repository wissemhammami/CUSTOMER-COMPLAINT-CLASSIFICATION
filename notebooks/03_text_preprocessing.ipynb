# %%
import os
os.chdir(r'C:\Users\Admin\Desktop\CUSTOMER COMPLAINT CLASSIFICATION')
print(os.getcwd())

# NOTE: cleaning is now handled inside the model pipeline (src/features/transformers.py::TextCleaner),
# not as a separate offline step, to avoid train/serve mismatch. This cell only demonstrates
# the cleaner in isolation for inspection purposes — it does NOT produce a separate preprocessed file.

from src.features.transformers import TextCleaner

sample = [
    "I was charged TWICE for the same transaction!! My bank refused to help.",
    "My mortgage payment was incorrectly applied to the wrong account."
]

cleaner = TextCleaner()
cleaned = cleaner.transform(sample)

for original, clean in zip(sample, cleaned):
    print(f"Original : {original}")
    print(f"Cleaned  : {clean}\n")
# Out:
# C:\Users\Admin\Desktop\CUSTOMER COMPLAINT CLASSIFICATION
# Original : I was charged TWICE for the same transaction!! My bank refused to help.
# Cleaned  : charged twice transaction bank refused help
#
# Original : My mortgage payment was incorrectly applied to the wrong account.
# Cleaned  : mortgage payment incorrectly applied wrong account
