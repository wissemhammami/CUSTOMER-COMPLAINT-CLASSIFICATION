# %%
import os
os.chdir(r'C:\Users\Admin\Desktop\CUSTOMER COMPLAINT CLASSIFICATION')
print(os.getcwd())
# Out:
# C:\Users\Admin\Desktop\CUSTOMER COMPLAINT CLASSIFICATION

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Load validated data
df = pd.read_csv('data/processed/complaints_validated.csv')

def clean_text(text):
    # Lowercase
    text = text.lower()
    # Remove punctuation and numbers
    text = re.sub(r'[^a-z\s]', '', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    # Remove stopwords
    text = ' '.join([w for w in text.split() if w not in stop_words])
    return text

# Apply cleaning
df['clean_text'] = df['text'].apply(clean_text)

# Quick check
print(df[['text', 'clean_text']].head(3))
print('Any nulls in clean_text:', df['clean_text'].isna().sum())

# Save
df[['clean_text', 'label']].to_csv('data/processed/complaints_preprocessed.csv', index=False)
print('saved successfully')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                 text  \
# 0  On or about XX/XX/XXXX, I noticed there were a...
# 1  I opened an Account with fifth third bank on X...
# 2  On or about XX/XX/XXXX my XXXX XXXX XXXX was r...
#
#                                           clean_text
# 0  xxxxxxxx noticed least unauthorized charges ch...
# 1  opened account fifth third bank xxxx xxxx trie...
# 2  xxxxxxxx xxxx xxxx xxxx repossessed date good ...
# Any nulls in clean_text: 0
# saved successfully
